# %% [markdown]
# **<font size=6> Exploratory Data Analysis (EDA)**
#
# ---

# %% [markdown]
# # Imports

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import tensorflow as tf

from dataloader.utils import get_count_classes, plot_classes, plot_from_one_class

SEED = 0

# %% [markdown]
# # Create Dataset

# %%
ds_train, ds_val = tf.keras.utils.image_dataset_from_directory(
    directory="tiny-imagenet-200/train/",
    batch_size=128,
    image_size=(64, 64),
    shuffle=True,
    seed=SEED,
    validation_split=0.2,
    subset="both"
    )
# Out:
# Found 100000 files belonging to 200 classes.
# Using 80000 files for training.
# Using 20000 files for validation.
# Metal device set to: Apple M1
# 2022-12-04 14:28:58.693147: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-12-04 14:28:58.693266: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %% [markdown]
# # Class distribution

# %%
class_counts = get_count_classes(ds_train)

class_counts.plot.hist(title="Distribution of class counts");
# Out:
# 2022-12-04 14:28:58.844678: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz

# %% [markdown]
# # Plot some random examples

# %%
plot_classes(ds_train)

# %% [markdown]
# # Plot a specific class

# %%
class_id = np.random.randint(len(ds_train.class_names))
plot_from_one_class(ds_train, class_id=class_id)
